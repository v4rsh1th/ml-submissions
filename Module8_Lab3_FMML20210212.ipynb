# %% [markdown]
# <a href="https://colab.research.google.com/github/v4rsh1th/ml-subs/blob/master/Module8_Lab3_FMML20210212.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# <table class="tfo-notebook-buttons" align="left">
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/drive/1TuDbIyso6irdyBFgaHRpC-PxUICWPHcS?usp=sharing"><img height="32px" src="https://colab.research.google.com/img/colab_favicon.ico" />Run in Google Colab</a>
#   </td>
#   <td>
#     <a target="_blank" href="https://github.com/Foundations-in-Modern-Machine-Learning/course-contents/tree/main/Bayesian/"><img src="https://www.tensorflow.org/images/GitHub-Mark-32px.png" />View source on GitHub</a>
#   </td>
# </table>
# <br>
# <br>
# <br>

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2022-06-10 17:33:03--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.111.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   314MB/s    in 0.2s
#
# 2022-06-10 17:33:04 (314 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False), 
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split() 
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 1617   1607.00424v1  We consider the task of KBP slot filling -- ex...    cs
# 22170  1506.04158v3  This paper presents a novel spectral algorithm...  stat
# 12252  1710.10769v1  Undirected graphical models compactly represen...  stat
# 6899   1707.03389v2  The natural world is infinitely diverse, yet t...  stat
# 11328  1509.09130v1  Recommending items to users is a challenging t...  stat
# ...             ...                                                ...   ...
# 31033  1802.01873v2  Each smile is unique: one person surely smiles...    cs
# 31728   0804.4741v1  This paper aims to showcase the measure of str...    cs
# 38798   1303.6361v1  Balancing computational efficiency with recogn...    cs
# 13029  1502.05023v2  In this paper we propose new techniques to sam...  stat
# 26721  1611.07145v1  In this paper, we propose a new deep network t...    cs
#
#                                                    title  year  \
# 1617   Learning Relational Dependency Networks for Re...  2016
# 22170  A Spectral Algorithm with Additive Clustering ...  2015
# 12252  Communication-Avoiding Optimization Methods fo...  2017
# 6899   SCAN: Learning Abstract Hierarchical Compositi...  2017
# 11328  Learning From Missing Data Using Selection Bia...  2015
# ...                                                  ...   ...
# 31033  Every Smile is Unique: Landmark-Guided Diverse...  2018
# 31728  The Effect of Structural Diversity of an Ensem...  2008
# 38798  Video Face Matching using Subset Selection and...  2013
# 13029               A New Sampling Technique for Tensors  2015
# 26721  Learning Multi-level Deep Representations for ...  2016
#
#                                                 keywords
# 1617   [extracting, information, documents, knowledge...
# 22170  [algorithm, clustering, overlapping, communiti...
# 12252  [undirected, graphical, compactly, represent, ...
# 6899   [infinitely, diversity, relatively, properties...
# 11328  [recommending, challenging, information, volun...
# ...                                                  ...
# 31033  [different, closingopening, distinctive, chara...
# 31728  [structural, diversity, classifiers, relations...
# 38798  [balancing, computational, efficiency, recogni...
# 13029  [techniques, arbitrary, objective, algorithms,...
# 26721  [representations, classification, recognized, ...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 1617     [extracting, information, documents, knowledge...
# 22170    [algorithm, clustering, overlapping, communiti...
# 12252    [undirected, graphical, compactly, represent, ...
# 6899     [infinitely, diversity, relatively, properties...
# 11328    [recommending, challenging, information, volun...
#                                ...
# 8715     [promising, direction, advancing, compression,...
# 5094     [predicting, plausible, relational, imperfect,...
# 6951     [annotated, sentiment, researchers, therefore,...
# 5736     [unsupervised, directions, identifiable, techn...
# 25069    [particular, distribution, important, frequent...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]), 
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8816 words.
# Out of those 4562 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="6302c02b-7cc1-431d-b365-d0a312d00f74" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6302c02b-7cc1-431d-b365-d0a312d00f74")) {                    Plotly.newPlot(                        "6302c02b-7cc1-431d-b365-d0a312d00f74",                        [{"x":["construction","components","knowledge","incorporated","extraction","benchmark","documents","linguistic","demonstrate","competitively","information","additionally","relational","different","extracting","dependency","supervision","effectively","framework","communities","overlapping","adjacency","consistent","clustering","stochastic","blockmodel","properties","simulated","geometric","logarithmic","algorithm","functional","conditional","automatically","literature","underlying","introduce","neuroscience","scientific","communication","outperform","interpreting","compactly","regularized","optimization","intractable","scalability","structure","important","terabytes","dimensional","covariance","represent","especially","agreement","dimensions","undirected","graphical","pseudolikelihood","describes","architecture","hierarchy","relatively","inference","disentangled","representing","operations","unsupervised","regularities","diversity","manipulations","chemistry","conjecture","intelligent","exponentially","representation","compositionality","compositional","recombine","environments","directional","traversal","descriptions","instructions","recombination","association","primarily","multimodal","previously","hierarchical","conceptual","primitives","generating","experiences","infinitely","biological","manipulation","discovering","representations","organisation","published","assumptions","available","variational","illustrate","recommendation","neighborhood","contributed","efficient","contribution","reliability","collaborative","voluntarily","computationally","unobserved","propensity","significant","challenging","populations","filtering","improving","potential","statistical","recommending","selection","approaches","estimation","markovian","generated","homogeneity","distribution","processes","considered","parametric","quadratic","stationary","appropriate","asymptotic","consistency","classical","algorithms","assumption","independence","generalizes","classification","classifiers","generalized","functions","simulation","boundaries","strengthen","classifier","significantly","superiority","correlated","definition","definitions","importance","comprehensive","according","addresses","numerical","mathematical","explained","determination","essentially","orthogonal","presentation","relevance","exponential","practical","formalisms","unrestricted","arbitrarily","polynomial","expressions","programming","translation","transformation","semantics","preliminary","transformed","disjunction","implemented","disjunctive","complexity","straightforward","challenge","resulting","reasoning","elementary","conjunction","introduced","illustrates","predefined","effective","development","illustrated","understand","observations"],"y":[71,108,343,36,145,212,61,89,562,5,762,63,37,774,85,32,59,120,553,17,24,5,75,153,113,0,230,48,73,17,798,44,87,192,119,114,333,15,38,50,92,15,5,44,288,28,33,321,359,0,171,24,112,118,16,42,10,34,0,80,243,36,66,225,5,85,80,136,7,47,1,3,10,66,25,352,4,18,1,87,23,2,40,5,4,34,18,47,107,101,17,8,96,10,10,38,18,32,248,3,33,56,299,59,79,27,28,1,397,62,22,29,2,92,7,1,252,266,16,64,107,146,155,6,146,457,201,7,169,4,193,105,146,47,30,32,90,15,53,90,545,76,31,25,525,129,71,219,74,36,3,156,261,37,27,38,19,87,57,110,43,69,58,14,15,24,28,11,42,45,140,12,7,18,59,54,115,111,61,100,53,26,6,98,7,230,21,163,155,139,13,15,148,4,17,268,131,20,70,78],"type":"bar"},{"x":["construction","components","knowledge","incorporated","ext ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4562,), (4562, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8141666666666667

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Coordinating</span> <span style='background-color:rgba(0, 255, 0, 0.7142857142857142);'>metaheuristic</span> <span style=''>agents</span> <span style=''>with</span> <span style=''>swarm</span> <span style='background-color:rgba(0, 255, 0, 0.7540983606557378);'>intelligence</span> <br/><br/><span style='background-color:rgba(0, 255, 0, 0.8000000000000002);'>Coordination</span> <span style=''>of</span> <span style=''>multi</span> <span style=''>agent</span> <span style=''>systems</span> <span style=''>remains</span> <span style=''>as</span> <span style=''>a</span> <span style=''>problem</span> <span style=''>since</span> <span style=''>there</span> <span style=''>is</span> <span style=''>no</span> <span style='background-color:rgba(0, 255, 0, 0.4545454545454546);'>prominent</span> <span style=''>method</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>completely</span> <span style=''>solve</span> <span style=''>this</span> <span style=''>problem</span> <span style='background-color:rgba(0, 255, 0, 0.7142857142857142);'>Metaheuristic</span> <span style=''>agents</span> <span style=''>are</span> <span style=''>specific</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>implementations</span> <span style=''>of</span> <span style=''>multi</span> <span style=''>agent</span> <span style=''>systems</span> <span style=''>which</span> <span style=''>imposes</span> <span style=''>working</span> <span style=''>together</span> <span style=''>to</span> <span style=''>solve</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimisation</span> <span style=''>problems</span> <span style=''>with</span> <span style='background-color:rgba(0, 255, 0, 0.7142857142857142);'>metaheuristic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithms</span> <span style=''>The</span> <span style=''>idea</span> <span style=''>borrowed</span> <span style=''>from</span> <span style=''>swarm</span> <span style='background-color:rgba(0, 255, 0, 0.7540983606557378);'>intelligence</span> <span style=''>seems</span> <span style=''>working</span> <span style=''>much</span> <span style=''>better</span> <span style=''>than</span> <span style=''>those</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>implementations</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>suggested</span> <span style=''>before</span> <span style=''>This</span> <span style=''>paper</span> <span style=''>reports</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>performance</span> <span style=''>of</span> <span style=''>swarms</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.492063492063492);'>simulated</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>annealing</span> <span style=''>agents</span> <span style='background-color:rgba(0, 255, 0, 0.3333333333333334);'>collaborating</span> <span style=''>with</span> <span style=''>particle</span> <span style=''>swarm</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimization</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>The</span> <span style=''>proposed</span> <span style=''>approach</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3706293706293706);'>implemented</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>multidimensional</span> <span style=''>knapsack</span> <span style=''>problem</span> <span style=''>and</span> <span style=''>has</span> <span style=''>resulted</span> <span style=''>much</span> <span style=''>better</span> <span style=''>than</span> <span style=''>some</span> <span style=''>other</span> <span style=''>works</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>published</span> <span style=''>before</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Max</span> <span style=''>value</span> <span style=''>Entropy</span> <span style=''>Search</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Efficient</span> <span style=''>Bayesian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Optimization</span> <br/><br/><span style=''>Entropy</span> <span style=''>Search</span> <span style=''>(ES)</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Predictive</span> <span style=''>Entropy</span> <span style=''>Search</span> <span style=''>(PES)</span> <span style=''>are</span> <span style=''>popular</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>empirically</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>successful</span> <span style=''>Bayesian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Optimization</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>techniques</span> <span style=''>Both</span> <span style=''>rely</span> <span style=''>on</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>compelling</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>information</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>theoretic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>motivation</span> <span style=''>and</span> <span style=''>maximize</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>information</span> <span style=''>gained</span> <span style=''>about</span> <span style=''>the</span> <span style=''>argmax</span> <span style=''>of</span> <span style=''>the</span> <span style=''>unknown</span> <span style=''>function</span> <span style=''>yet</span> <span style=''>both</span> <span style=''>are</span> <span style=''>plagued</span> <span style=''>by</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>expensive</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>computation</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimating</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>entropies</span> <span style=''>We</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>new</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>criterion</span> <span style=''>Max</span> <span style=''>value</span> <span style=''>Entropy</span> <span style=''>Search</span> <span style=''>(MES)</span> <span style=''>that</span> <span style=''>instead</span> <span style=''>uses</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>information</span> <span style=''>about</span> <span style=''>the</span> <span style=''>maximum</span> <span style=''>function</span> <span style=''>value</span> <span style=''>We</span> <span style=''>show</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>relations</span> <span style=''>of</span> <span style=''>MES</span> <span style=''>to</span> <span style=''>other</span> <span style=''>Bayesian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimization</span> <span style=''>methods</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>establish</span> <span style=''>a</span> <span style=''>regret</span> <span style=''>bound</span> <span style=''>We</span> <span style=''>observe</span> <span style=''>that</span> <span style=''>MES</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>maintains</span> <span style=''>or</span> <span style=''>improves</span> <span style=''>the</span> <span style=''>good</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>empirical</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>performance</span> <span style=''>of</span> <span style=''>ESPES</span> <span style=''>while</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>tremendously</span> <span style ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>On</span> <span style=''>the</span> <span style=''>Size</span> <span style=''>of</span> <span style=''>the</span> <span style=''>Online</span> <span style=''>Kernel</span> <span style='background-color:rgba(255, 0, 0, 0.5555555555555555);'>Sparsification</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Dictionary</span> <br/><br/><span style=''>We</span> <span style=''>analyze</span> <span style=''>the</span> <span style=''>size</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dictionary</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>constructed</span> <span style=''>from</span> <span style=''>online</span> <span style=''>kernel</span> <span style='background-color:rgba(255, 0, 0, 0.5555555555555555);'>sparsification</span> <span style=''>using</span> <span style=''>a</span> <span style=''>novel</span> <span style=''>formula</span> <span style=''>that</span> <span style='background-color:rgba(0, 255, 0, 0.33333333333333337);'>expresses</span> <span style=''>the</span> <span style=''>expected</span> <span style='background-color:rgba(0, 255, 0, 0.3333333333333334);'>determinant</span> <span style=''>of</span> <span style=''>the</span> <span style=''>kernel</span> <span style=''>Gram</span> <span style=''>matrix</span> <span style=''>in</span> <span style=''>terms</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.5555555555555555);'>eigenvalues</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.6);'>covariance</span> <span style=''>operator</span> <span style=''>Using</span> <span style=''>this</span> <span style=''>formula</span> <span style=''>we</span> <span style=''>are</span> <span style=''>able</span> <span style=''>to</span> <span style=''>connect</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>cardinality</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dictionary</span> <span style=''>with</span> <span style=''>the</span> <span style=''>eigen</span> <span style=''>decay</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.6);'>covariance</span> <span style=''>operator</span> <span style=''>In</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>particular</span> <span style=''>we</span> <span style=''>show</span> <span style=''>that</span> <span style=''>under</span> <span style=''>certain</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>technical</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>conditions</span> <span style=''>the</span> <span style=''>size</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dictionary</span> <span style=''>will</span> <span style=''>always</span> <span style=''>grow</span> <span style=''>sub</span> <span style=''>linearly</span> <span style=''>in</span> <span style=''>the</span> <span style=''>number</span> <span style=''>of</span> <span style=''>data</span> <span style=''>points</span> <span style=''>and</span> <span style=''>as</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>consequence</span> <span style=''>the</span> <span style=''>kernel</span> <span style=''>linear</span> <span style='background-color:rgba(0, 255, 0, 0.3333333333333334);'>regressor</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>constructed</span> <span style=''>from</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>resulting</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dictionary</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>consistent</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Diffusion</span> <span style=''>Nets</span> <br/><br/><span style=''>Non</span> <span style=''>linear</span> <span style=''>manifold</span> <span style=''>learning</span> <span style=''>enables</span> <span style=''>high</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensional</span> <span style=''>data</span> <span style=''>analysis</span> <span style=''>but</span> <span style=''>requires</span> <span style=''>out</span> <span style=''>of</span> <span style=''>sample</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>extension</span> <span style=''>methods</span> <span style=''>to</span> <span style=''>process</span> <span style=''>new</span> <span style=''>data</span> <span style=''>points</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>manifold</span> <span style=''>learning</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>based</span> <span style=''>on</span> <span style=''>deep</span> <span style=''>learning</span> <span style=''>to</span> <span style=''>create</span> <span style=''>an</span> <span style=''>encoder</span> <span style=''>which</span> <span style=''>maps</span> <span style=''>a</span> <span style=''>high</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensional</span> <span style=''>dataset</span> <span style=''>and</span> <span style=''>its</span> <span style=''>low</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensional</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>embedding</span> <span style=''>and</span> <span style=''>a</span> <span style=''>decoder</span> <span style=''>which</span> <span style=''>takes</span> <span style=''>the</span> <span style=''>embedded</span> <span style=''>data</span> <span style=''>back</span> <span style=''>to</span> <span style=''>the</span> <span style=''>high</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensional</span> <span style=''>space</span> <span style=''>Stacking</span> <span style=''>the</span> <span style=''>encoder</span> <span style=''>and</span> <span style=''>decoder</span> <span style=''>together</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>constructs</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>autoencoder</span> <span style=''>which</span> <span style=''>we</span> <span style=''>term</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>diffusion</span> <span style=''>net</span> <span style=''>that</span> <span style=''>performs</span> <span style=''>out</span> <span style=''>of</span> <span style=''>sample</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>extension</span> <span style=''>as</span> <span style=''>well</span> <span style=''>as</span> <span style=''>outlier</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>detection</span> <span style=''>We</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>introduce</span> <span style=''>new</span> <span style=''>neural</span> <span style=''>net</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>constraints</span> <span style=''>for</span> <span style=''>the</span> <span style=''>encoder</span> <span style=''>which</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>preserves</span> <span style=''>the</span> <span style=''>local</span> <span style=''>geometry</span> <span style=''>of</span> <span style=''>the</span> <span style=''>points</span> <span style=''>and</span> <span style=''>we</span> <span style=''>prove</span> <span style=''>rates</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>convergence</span> <span style=''>for</span> <span style=''>the</span> <span style=''>encoder</span> <span style=''>Also</span> <span style=''>our ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	processing (0.09763948497854077)
# 	representation (0.12589413447782546)
# 	evaluation (0.0944206008583691)
# 	experimental (0.1323319027181688)
# 	architecture (0.08690987124463519)
# 	detection (0.1226752503576538)
# 	information (0.27253218884120173)
# 	different (0.27682403433476394)
# 	recognition (0.13590844062947066)
# 	convolutional (0.1427038626609442)
#
# Some Statistics words are:
# 	distributions (0.12425149700598802)
# 	theoretical (0.14820359281437126)
# 	stochastic (0.13572854291417166)
# 	algorithm (0.3847305389221557)
# 	variables (0.1377245508982036)
# 	inference (0.18413173652694612)
# 	estimation (0.1781437125748503)
# 	distribution (0.18512974051896208)
# 	regression (0.16766467065868262)
# 	dimensional (0.19560878243512975)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]), 
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="850b1892-03fc-4f9b-b7de-101acba38639" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("850b1892-03fc-4f9b-b7de-101acba38639")) {                    Plotly.newPlot(                        "850b1892-03fc-4f9b-b7de-101acba38639",                        [{"x":["construction","components","knowledge","incorporated","extraction","benchmark","documents","linguistic","demonstrate","competitively","information","additionally","relational","different","extracting","dependency","supervision","effectively","framework","communities","overlapping","adjacency","consistent","clustering","stochastic","blockmodel","properties","simulated","geometric","logarithmic","algorithm","functional","conditional","automatically","literature","underlying","introduce","neuroscience","scientific","communication","outperform","interpreting","compactly","regularized","optimization","intractable","scalability","structure","important","terabytes","dimensional","covariance","represent","especially","agreement","dimensions","undirected","graphical","pseudolikelihood","describes","architecture","hierarchy","relatively","inference","disentangled","representing","operations","unsupervised","regularities","diversity","manipulations","chemistry","conjecture","intelligent","exponentially","representation","compositionality","compositional","recombine","environments","directional","traversal","descriptions","instructions","recombination","association","primarily","multimodal","previously","hierarchical","conceptual","primitives","generating","experiences","infinitely","biological","manipulation","discovering","representations","organisation","published","assumptions","available","variational","illustrate","recommendation","neighborhood","contributed","efficient","contribution","reliability","collaborative","voluntarily","computationally","unobserved","propensity","significant","challenging","populations","filtering","improving","potential","statistical","recommending","selection","approaches","estimation","markovian","generated","homogeneity","distribution","processes","considered","parametric","quadratic","stationary","appropriate","asymptotic","consistency","classical","algorithms","assumption","independence","generalizes","classification","classifiers","generalized","functions","simulation","boundaries","strengthen","classifier","significantly","superiority","correlated","definition","definitions","importance","comprehensive","according","addresses","numerical","mathematical","explained","determination","essentially","orthogonal","presentation","relevance","exponential","practical","formalisms","unrestricted","arbitrarily","polynomial","expressions","programming","translation","transformation","semantics","preliminary","transformed","disjunction","implemented","disjunctive","complexity","straightforward","challenge","resulting","reasoning","elementary","conjunction","introduced","illustrates","predefined","effective","development","illustrated","understand","observations","questions","partially","extracted","usefulness","maintaining","interested","meanwhile","theoretical","specifically","significance","difference","synthetic","multicore","convergence","complement","understood","mechanism","frequency","independently","objectives","experiments","averaging","augmentation","approximating","substantial","augmented","variables","connection","rigorously","generalization","characterize","guarantee","likelihoods","approximations","condition","obtainable","interpreted","divergence","minimizing","posterior","interpretation","characteristics","discriminative","transferring","interfacing","stationarities","subspaces","meaningful","estimated","performing","shrinking","invariant","operation", ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	blockmodel
# 	terabytes
# 	pseudolikelihood
# 	interfacing
# 	stationarities
# 	transelliptical
# 	marginalized
# 	isomorphism
# 	borrowings
# 	reparametrizations
# 	autoencoding
# 	iterating
# 	staleness
# 	asynchrony
# 	encountering
# 	precisionk
# 	eigendecomposition
# 	certainly
# 	conjugacy
# 	scientist
# Some words which never appear in Statistics papers:
# 	formalisms
# 	disjunction
# 	watershed
# 	rudimentary
# 	fluorescent
# 	delineate
# 	functionalities
# 	photography
# 	assistant
# 	conversational
# 	counterfactuals
# 	clarifying
# 	surpassed
# 	something
# 	depiction
# 	monocular
# 	photometric
# 	possibilistic
# 	interfering
# 	accelerometer

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.074841645655249e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.77
