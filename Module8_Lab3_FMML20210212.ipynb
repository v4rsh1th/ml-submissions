# %% [markdown]
# <a href="https://colab.research.google.com/github/v4rsh1th/ml-subs/blob/master/Module8_Lab3_FMML20210212.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# <table class="tfo-notebook-buttons" align="left">
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/drive/1TuDbIyso6irdyBFgaHRpC-PxUICWPHcS?usp=sharing"><img height="32px" src="https://colab.research.google.com/img/colab_favicon.ico" />Run in Google Colab</a>
#   </td>
#   <td>
#     <a target="_blank" href="https://github.com/Foundations-in-Modern-Machine-Learning/course-contents/tree/main/Bayesian/"><img src="https://www.tensorflow.org/images/GitHub-Mark-32px.png" />View source on GitHub</a>
#   </td>
# </table>
# <br>
# <br>
# <br>

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2022-06-10 17:39:59--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json.1’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   278MB/s    in 0.2s
#
# 2022-06-10 17:39:59 (278 MB/s) - ‘arxiv-paper-data.json.1’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False), 
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split() 
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 15883  1606.04640v1  We present the Siamese Continuous Bag of Words...    cs
# 34804  cs/0006005v1  The ability of a robot to detect and respond t...    cs
# 23030  1802.04908v1  Modeling complex conditional distributions is ...  stat
# 11153   1410.6853v2  Mean Field Variational Bayes (MFVB) is a popul...  stat
# 22948  1711.07561v1  This is a technical report which explores the ...  stat
# ...             ...                                                ...   ...
# 29915  1711.00648v5  It is a difficult task to classify images with...    cs
# 3779    1409.6045v1  Many signal processing and machine learning me...  stat
# 19648   1406.0955v2  In this paper, we proposed a new approximate h...    cs
# 22752  1705.10378v4  In this paper, we consider the problem of fair...  stat
# 25821  1511.07963v1  The method of using video cameras installed on...    cs
#
#                                                    title  year  \
# 15883  Siamese CBOW: Optimizing Word Embeddings for S...  2016
# 34804               Novelty Detection for Robot Neotaxis  2000
# 23030  Conditional Density Estimation with Bayesian N...  2018
# 11153  Covariance Matrices for Mean Field Variational...  2014
# 22948             Review on Parameter Estimation in HMRF  2017
# ...                                                  ...   ...
# 29915  Data Augmentation in Emotion Classification Us...  2017
# 3779   Analyzing sparse dictionaries for online learn...  2014
# 19648  Cascading A*: a Parallel Approach to Approxima...  2014
# 22752                         Fair Inference On Outcomes  2017
# 25821  Calculate distance to object in the area where...  2015
#
#                                                 keywords
# 15883  [continuous, efficient, estimation, embeddings...
# 34804  [environment, potentially, attention, potentia...
# 23030  [conditional, distributions, tradition, condit...
# 11153  [variational, posterior, approximation, undere...
# 22948  [technical, estimation, methodologies, paramet...
# ...                                                  ...
# 29915  [difficult, especially, distribution, imbalanc...
# 3779   [processing, essentially, parameter, parameter...
# 19648  [approximate, heuristic, algorithm, cascading,...
# 22752  [statistical, inference, involving, variables,...
# 25821                  [installed, calculate, calculate]
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 15883    [continuous, efficient, estimation, embeddings...
# 34804    [environment, potentially, attention, potentia...
# 23030    [conditional, distributions, tradition, condit...
# 11153    [variational, posterior, approximation, undere...
# 22948    [technical, estimation, methodologies, paramet...
#                                ...
# 25886    [descriptors, conventionally, performed, alter...
# 12553    [vulnerable, adversarial, malicious, perturbat...
# 10381    [distributed, dictionary, collectively, dictio...
# 27576    [detection, recognition, delightful, recogniti...
# 22681    [reproducing, associated, divergence, conditio...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]), 
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8662 words.
# Out of those 4534 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="ab32df16-65fe-43bf-b121-0fb28207e8f7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ab32df16-65fe-43bf-b121-0fb28207e8f7")) {                    Plotly.newPlot(                        "ab32df16-65fe-43bf-b121-0fb28207e8f7",                        [{"x":["available","underlying","averaging","efficient","optimized","optimizing","currently","continuous","suboptimal","embeddings","representation","sentences","surrounding","predicting","obtaining","successful","robustness","surprisingly","representations","evaluating","estimation","previously","potentially","presented","experienced","habituation","important","attention","biological","presentation","concentration","detection","experiments","environment","algorithm","variational","functional","tradition","conditional","decisions","distributional","estimators","densities","datapoints","recognize","parametric","benchmark","regression","complexity","difficult","overfitting","heteroscedasticity","likelihood","performance","distributions","framework","approximating","methodology","individual","perturbing","exponential","uncertainty","estimates","demonstrate","approximation","underestimates","information","simulated","posterior","covariance","variables","coherently","technical","estimating","parameters","parameter","metropolis","following","performed","discusses","methodologies","theoretical","investigate","supporting","resources","structural","classifies","according","linguistic","properties","systematic","multilingual","published","importance","languages","discussion","recognised","processing","frequently","simulation","conventional","clustering","particularly","disorders","identification","subgroups","biomedical","associated","homogeneous","identifies","scenarios","microarray","interesting","particular","correctly","applications","generally","secondary","biologically","modification","prospective","evaluator","calibration","contributions","normalized","practical","magnitude","underestimated","databases","calibrate","operating","reasonable","principles","principled","requirements","optimizer","initially","challenges","criterion","challenge","evaluation","algorithms","solutions","participants","facilitates","basically","generator","candidate","comprises","conducted","suggestions","sensitive","including","processes","dictionaries","character","contextual","vocabulary","reduction","dictionary","providing","generates","sequences","documents","correction","outstanding","correcting","extracted","terminologies","computing","different","detecting","statistics","fundamentally","sparseness","incorrectly","containing","parallelized","sometimes","computational","separated","proximity","consequently","automatically","requiring","physically","redundant","structure","restricts","organized","descending","neighbors","representing","undesired","generality","recommendation","inference","naturally","advertising","outperform"],"y":[308,122,22,384,45,51,49,129,8,74,365,77,16,78,35,61,103,39,223,58,221,93,52,188,6,2,338,147,47,9,13,340,605,136,858,54,36,2,106,52,17,10,3,1,44,50,229,116,227,150,20,0,65,875,117,535,22,65,86,1,34,89,79,531,142,0,722,63,52,26,134,1,37,66,243,124,3,97,142,23,18,178,143,28,67,78,8,120,81,207,37,19,32,88,86,24,1,280,27,76,102,145,79,6,91,2,15,114,14,27,91,7,71,251,25,433,67,6,5,22,0,1,16,48,31,147,62,1,61,2,23,38,40,24,46,4,17,110,40,148,269,591,139,19,9,6,32,61,16,84,4,56,280,106,18,51,54,33,89,48,81,43,103,66,25,11,10,109,2,142,720,70,65,5,8,3,50,5,26,305,10,8,25,167,43,5,23,336,2,18,1,21,79,5,5,27,205,71,9,94],"type":"bar"},{"x":["available","underlying","averaging","efficient","optimized","optimizing","currently","continuous","suboptimal","embeddings","representation","sentences","surrou ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4534,), (4534, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7966666666666666

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.7777777777777777);'>Fractional</span> <span style=''>Calculus</span> <span style=''>In</span> <span style=''>Image</span> <span style='background-color:rgba(0, 255, 0, 0.41414141414141403);'>Processing</span> <span style=''>A</span> <span style=''>Review</span> <br/><br/><span style=''>Over</span> <span style=''>the</span> <span style=''>last</span> <span style=''>decade</span> <span style=''>it</span> <span style=''>has</span> <span style=''>been</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>demonstrated</span> <span style=''>that</span> <span style=''>many</span> <span style=''>systems</span> <span style=''>in</span> <span style=''>science</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.30337078651685395);'>engineering</span> <span style=''>can</span> <span style=''>be</span> <span style=''>modeled</span> <span style=''>more</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>accurately</span> <span style=''>by</span> <span style='background-color:rgba(0, 255, 0, 0.7777777777777777);'>fractional</span> <span style=''>order</span> <span style=''>than</span> <span style=''>integer</span> <span style=''>order</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>derivatives</span> <span style=''>and</span> <span style=''>many</span> <span style=''>methods</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>developed</span> <span style=''>to</span> <span style=''>solve</span> <span style=''>the</span> <span style=''>problem</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.7777777777777777);'>fractional</span> <span style=''>systems</span> <span style=''>Due</span> <span style=''>to</span> <span style=''>the</span> <span style=''>extra</span> <span style=''>free</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>parameter</span> <span style=''>order</span> <span style='background-color:rgba(0, 255, 0, 0.7777777777777777);'>fractional</span> <span style=''>order</span> <span style=''>based</span> <span style=''>methods</span> <span style=''>provide</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>additional</span> <span style=''>degree</span> <span style=''>of</span> <span style=''>freedom</span> <span style=''>in</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimization</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>performance</span> <span style=''>Not</span> <span style='background-color:rgba(0, 255, 0, 0.34482758620689646);'>surprisingly</span> <span style=''>many</span> <span style='background-color:rgba(0, 255, 0, 0.7777777777777777);'>fractional</span> <span style=''>order</span> <span style=''>based</span> <span style=''>methods</span> <span style=''>have</span> <span style=''>been</span> <span style=''>used</span> <span style=''>in</span> <span style=''>image</span> <span style='background-color:rgba(0, 255, 0, 0.41414141414141403);'>processing</span> <span style=''>field</span> <span style=''>Herein</span> <span style=''>recent</span> <span style=''>studies</span> <span style=''>are</span> <span style=''>reviewed</span> <span style=''>in</span> <span style=''>ten</span> <span style=''>sub</span> <span style=''>fields</span> <span style=''>which</span> <span style=''>include</span> <span style=''>image</span> <span style='background-color:rgba(0, 255, 0, 0.7058823529411765);'>enhancement</span> <span style=''>image</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>denoising</span> <span style=''>image</span> <span style=''>edge</span> <span style='background-color:rgba(0, 255, 0, 0.5315315315315314);'>detection</span> <span style=''>image</span> <span style='background-color:rgba(0, 255, 0, 0.7399103139013452);'>segmentation</span> <span style=''>image</span> <span style='background-color:rgba(0, 255, 0, 0.7500000000000001);'>registration</span> <span style=''>image</span> <span style='backgrou ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Sublinear</span> <span style=''>Time</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Approximate</span> <span style=''>MCMC</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Transitions</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Probabilistic</span> <span style=''>Programs</span> <br/><br/><span style='background-color:rgba(0, 255, 0, 0.3);'>Probabilistic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>programming</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>languages</span> <span style=''>can</span> <span style=''>simplify</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>development</span> <span style=''>of</span> <span style=''>machine</span> <span style=''>learning</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>techniques</span> <span style=''>but</span> <span style=''>only</span> <span style=''>if</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inference</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>sufficiently</span> <span style=''>scalable</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Unfortunately</span> <span style=''>Bayesian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parameter</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimation</span> <span style=''>for</span> <span style=''>highly</span> <span style=''>coupled</span> <span style=''>models</span> <span style=''>such</span> <span style=''>as</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regressions</span> <span style=''>and</span> <span style=''>state</span> <span style=''>space</span> <span style=''>models</span> <span style=''>still</span> <span style=''>scales</span> <span style=''>poorly</span> <span style=''>each</span> <span style=''>MCMC</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>transition</span> <span style=''>takes</span> <span style=''>linear</span> <span style=''>time</span> <span style=''>in</span> <span style=''>the</span> <span style=''>number</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>observations</span> <span style=''>This</span> <span style=''>paper</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>describes</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>sublinear</span> <span style=''>time</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>for</span> <span style=''>making</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Metropolis</span> <span style=''>Hastings</span> <span style=''>(MH)</span> <span style=''>updates</span> <span style=''>to</span> <span style=''>latent</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variables</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>probabilistic</span> <span style=''>programs</span> <span style=''>The</span> <span style=''>approach</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generalizes</span> <span style=''>recently</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>introduced</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approximate</span> <span style=''>MH</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>techniques</span> <span style=''>instead</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>subsampling</span> <span style=''>data</span> <span style=''>items</span> <span style=''>assumed</span> <span style=''>to</span> <span style=''>be</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>independent</span> <span style=''>it</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>subsamples</span> <span style=''>edges</span> <span style=''>in</span> <span style=''>a</span> <span style='background-colo ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>A</span> <span style=''>Bayesian</span> <span style=''>Matrix</span> <span style='background-color:rgba(255, 0, 0, 0.4890510948905109);'>Factorization</span> <span style=''>Model</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.4000000000000001);'>Relational</span> <span style=''>Data</span> <br/><br/><span style='background-color:rgba(0, 255, 0, 0.4000000000000001);'>Relational</span> <span style=''>learning</span> <span style=''>can</span> <span style=''>be</span> <span style=''>used</span> <span style=''>to</span> <span style=''>augment</span> <span style=''>one</span> <span style=''>data</span> <span style=''>source</span> <span style=''>with</span> <span style=''>other</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>correlated</span> <span style=''>sources</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3545966228893058);'>information</span> <span style=''>to</span> <span style=''>improve</span> <span style='background-color:rgba(255, 0, 0, 0.4375000000000001);'>predictive</span> <span style=''>accuracy</span> <span style=''>We</span> <span style=''>frame</span> <span style=''>a</span> <span style=''>large</span> <span style=''>class</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.4000000000000001);'>relational</span> <span style=''>learning</span> <span style=''>problems</span> <span style=''>as</span> <span style=''>matrix</span> <span style='background-color:rgba(255, 0, 0, 0.4890510948905109);'>factorization</span> <span style=''>problems</span> <span style=''>and</span> <span style=''>propose</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>hierarchical</span> <span style=''>Bayesian</span> <span style=''>model</span> <span style=''>Training</span> <span style=''>our</span> <span style=''>Bayesian</span> <span style=''>model</span> <span style=''>using</span> <span style=''>random</span> <span style=''>walk</span> <span style='background-color:rgba(255, 0, 0, 0.49999999999999994);'>Metropolis</span> <span style=''>Hastings</span> <span style=''>is</span> <span style=''>impractically</span> <span style=''>slow</span> <span style=''>and</span> <span style=''>so</span> <span style=''>we</span> <span style=''>develop</span> <span style=''>a</span> <span style=''>block</span> <span style='background-color:rgba(255, 0, 0, 0.49999999999999994);'>Metropolis</span> <span style=''>Hastings</span> <span style=''>sampler</span> <span style=''>which</span> <span style=''>uses</span> <span style=''>the</span> <span style=''>gradient</span> <span style=''>and</span> <span style=''>Hessian</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.516728624535316);'>likelihood</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.5272727272727273);'>dynamically</span> <span style=''>tune</span> <span style=''>the</span> <span style=''>proposal</span> <span style=''>We</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>demonstrate</span> <span style=''>that</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.4375000000000001);'>predictive</span> <span style=''>model</span> <span style=''>of</span> <span style=''>brain</span> <span style=''>response</span> <span style=''>to</span> <span style=''>stimuli</span> <span style=''>can</span> <span style=''>be</span> <span style=''>improved</span> <span style=''>by</span> <span style='background-color:rgba(0, 255, 0, 0.47826086956521735);'>augmenting</span> <span style=''>it</span> <span style=''>with</span> <span style=''>side</span> <span style='background-color:rgba(0, 255, 0, 0.3545966228893058);'>information</span> <span style=''>about</span> <span style=''>the</span> <span style=''>stimuli</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>High</span> <span style=''>Quality</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Prediction</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Intervals</span> <span style=''>for</span> <span style=''>Deep</span> <span style=''>Learning</span> <span style=''>A</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Distribution</span> <span style=''>Free</span> <span style=''>Ensembled</span> <span style=''>Approach</span> <br/><br/><span style=''>Deep</span> <span style=''>neural</span> <span style=''>networks</span> <span style=''>are</span> <span style=''>a</span> <span style=''>powerful</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>technique</span> <span style=''>for</span> <span style=''>learning</span> <span style=''>complex</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>functions</span> <span style=''>from</span> <span style=''>data</span> <span style=''>However</span> <span style=''>their</span> <span style=''>appeal</span> <span style=''>in</span> <span style=''>real</span> <span style=''>world</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>applications</span> <span style=''>can</span> <span style=''>be</span> <span style=''>hindered</span> <span style=''>by</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>inability</span> <span style=''>to</span> <span style=''>quantify</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>uncertainty</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>predictions</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>generation</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>prediction</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>intervals</span> <span style=''>(PI)</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>quantifying</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>uncertainty</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regression</span> <span style=''>tasks</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>considered</span> <span style=''>It</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>axiomatic</span> <span style=''>that</span> <span style=''>high</span> <span style=''>quality</span> <span style=''>PIs</span> <span style=''>should</span> <span style=''>be</span> <span style=''>as</span> <span style=''>narrow</span> <span style=''>as</span> <span style=''>possible</span> <span style=''>whilst</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>capturing</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>specified</span> <span style=''>portion</span> <span style=''>of</span> <span style=''>data</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>derive</span> <span style=''>a</span> <span style=''>loss</span> <span style=''>function</span> <span style=''>directly</span> <span style=''>from</span> <span style=''>this</span> <span style=''>high</span> <span style=''>quality</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>principle</span> <span style=''>that</span> <span style=''>requires</span> <span style=''>no</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distributional</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>assumption</span> <span style=''>We</span> <span style=''>show</span> <span style=''>how</span> <span style=''>its</span> <span style=''>form</span> <span style=''>derives</span> <span style=''>from</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>likelihood</span> <span styl ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	automatic (0.07428571428571429)
# 	architecture (0.08571428571428572)
# 	segmentation (0.06928571428571428)
# 	experimental (0.1407142857142857)
# 	representation (0.13035714285714287)
# 	detection (0.12142857142857143)
# 	different (0.2571428571428571)
# 	recognition (0.12642857142857142)
# 	convolutional (0.13285714285714287)
# 	information (0.25785714285714284)
#
# Some Statistics words are:
# 	stochastic (0.1335)
# 	theoretical (0.1565)
# 	algorithm (0.4015)
# 	variables (0.144)
# 	statistical (0.1525)
# 	estimation (0.184)
# 	distribution (0.188)
# 	inference (0.191)
# 	dimensional (0.197)
# 	regression (0.18)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]), 
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="7b64ac78-7b67-4ace-a7c7-3a957e7c5374" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7b64ac78-7b67-4ace-a7c7-3a957e7c5374")) {                    Plotly.newPlot(                        "7b64ac78-7b67-4ace-a7c7-3a957e7c5374",                        [{"x":["available","underlying","averaging","efficient","optimized","optimizing","currently","continuous","suboptimal","embeddings","representation","sentences","surrounding","predicting","obtaining","successful","robustness","surprisingly","representations","evaluating","estimation","previously","potentially","presented","experienced","habituation","important","attention","biological","presentation","concentration","detection","experiments","environment","algorithm","variational","functional","tradition","conditional","decisions","distributional","estimators","densities","datapoints","recognize","parametric","benchmark","regression","complexity","difficult","overfitting","heteroscedasticity","likelihood","performance","distributions","framework","approximating","methodology","individual","perturbing","exponential","uncertainty","estimates","demonstrate","approximation","underestimates","information","simulated","posterior","covariance","variables","coherently","technical","estimating","parameters","parameter","metropolis","following","performed","discusses","methodologies","theoretical","investigate","supporting","resources","structural","classifies","according","linguistic","properties","systematic","multilingual","published","importance","languages","discussion","recognised","processing","frequently","simulation","conventional","clustering","particularly","disorders","identification","subgroups","biomedical","associated","homogeneous","identifies","scenarios","microarray","interesting","particular","correctly","applications","generally","secondary","biologically","modification","prospective","evaluator","calibration","contributions","normalized","practical","magnitude","underestimated","databases","calibrate","operating","reasonable","principles","principled","requirements","optimizer","initially","challenges","criterion","challenge","evaluation","algorithms","solutions","participants","facilitates","basically","generator","candidate","comprises","conducted","suggestions","sensitive","including","processes","dictionaries","character","contextual","vocabulary","reduction","dictionary","providing","generates","sequences","documents","correction","outstanding","correcting","extracted","terminologies","computing","different","detecting","statistics","fundamentally","sparseness","incorrectly","containing","parallelized","sometimes","computational","separated","proximity","consequently","automatically","requiring","physically","redundant","structure","restricts","organized","descending","neighbors","representing","undesired","generality","recommendation","inference","naturally","advertising","outperform","techniques","developments","combining","additionally","sequential","empirical","successfully","increased","hierarchical","encompasses","inferential","approaches","encouraged","architecture","implemented","frameworks","contribute","hyperparameter","researchers","adaptability","automated","optimization","confounders","independence","consistently","estimated","distorted","assumptions","violation","artificial","influences","effectiveness","intelligence","furthermore","introduce","propositional","randomized","polynomial","constraints","algorithmic","approximate","functions","probabilistic","demonstrated","innovations","fundamental","potential","expressed","markovian","crucially","optimality","computable","probability","recoverability","exploration","sublinear","nonparametric","subjective","stochast ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	heteroscedasticity
# 	underestimates
# 	prospective
# 	confounders
# 	narrowing
# 	emphstructured
# 	prespecified
# 	automates
# 	convolved
# 	prognostics
# 	whitening
# 	individualized
# 	prognostic
# 	stabilizing
# 	homogenous
# 	heteroskedastic
# 	weightings
# 	precisionk
# 	reciprocity
# 	faithfulness
# Some words which never appear in Statistics papers:
# 	habituation
# 	terminologies
# 	propositional
# 	subjective
# 	misbehave
# 	concatenate
# 	entertainment
# 	occlusions
# 	subtracted
# 	admissible
# 	surpassed
# 	unfeasible
# 	impressive
# 	achievements
# 	fixations
# 	conversational
# 	switchboard
# 	telephone
# 	transformer
# 	photographers

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.07370750599373e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7458333333333333
